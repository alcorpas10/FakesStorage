# %%
# Si se quiere ejecutar el código hay que instalar selenium y tener chromedriver en el path
# pip install selenium

# %%
pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.1.0-py3-none-any.whl (958 kB)
# Collecting trio~=0.17
#   Downloading trio-0.19.0-py3-none-any.whl (356 kB)
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: urllib3[secure]~=1.26 in c:\programdata\anaconda3\lib\site-packages (from selenium) (1.26.4)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: cffi>=1.14 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.5)
# Collecting outcome
#   Downloading outcome-1.1.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (20.3.0)
# Requirement already satisfied: sortedcontainers in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.3.0)
# Requirement already satisfied: async-generator>=1.9 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (2020.12.5)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\programdata\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (20.0.1)
# Requirement already satisfied: cryptography>=1.3.4 in c:\programdata\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (3.4.7)
# Requirement already satisfied: six>=1.5.2 in c:\programdata\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.15.0)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
# Installing collected packages: outcome, h11, wsproto, trio, trio-websocket, selenium
# Successfully installed h11-0.12.0 outcome-1.1.0 selenium-4.1.0 trio-0.19.0 trio-websocket-0.9.2 wsproto-1.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
import time
import math
import json

# %%
driver = webdriver.Chrome()
driver.get('https://www.newtral.es/fakes/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      70             cmd.extend(self.command_line_args())
# ---> 71             self.process = subprocess.Popen(cmd, env=self.env,
#      72                                             close_fds=system() != 'Windows',
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     857
# --> 858             self._execute_child(args, executable, preexec_fn, close_fds,
#     859                                 pass_fds, cwd, env,
#
# C:\ProgramData\Anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1310             try:
# -> 1311                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1312                                          # no special security
#
# FileNotFoundError: [WinError 2] El sistema no puede encontrar el archivo especificado
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-3-6047260cee3c> in <module>
# ----> 1 driver = webdriver.Chrome()
#       2 driver.get('https://www.newtral.es/fakes/')
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, service, keep_alive)
#      68             service = Service(executable_path, port, service_args, service_log_path)
#      69
# ---> 70         super(WebDriver, self).__init__(DesiredCapabilities.CHROME['browserName'], "goog",
#      71                                         port, options,
#      72                                         service_args, desired_capabilities,
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\chromium\webdriver.py in __init__(self, browser_name, vendor_prefix, port, options, service_args, desired_capabilities, service_log_path, service, keep_alive)
#      88
#      89         self.service = service
# ---> 90         self.service.start()
#      91
#      92         try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      79         except OSError as err:
#      80             if err.errno == errno.ENOENT:
# ---> 81                 raise WebDriverException(
#      82                     "'%s' executable needs to be in PATH. %s" % (
#      83                         os.path.basename(self.path), self.start_error_message)
#
# WebDriverException: Message: 'chromedriver' executable needs to be in PATH. Please see https://chromedriver.chromium.org/home

# %%
button = driver.find_element(By.ID, 'onetrust-reject-all-handler')
button.click()

# %%
num_bulos = int(driver.find_element(By.CLASS_NAME, 'results-count').text[1:-1])
num_clicks = math.floor(num_bulos / 15)
(num_bulos, num_clicks)

# %%
button = driver.find_element(By.ID, 'scroll-load-more')
delay = 5
for i in range(num_clicks):       
    try:
        # And press the button
        button.click()
        
        time.sleep(delay)
    except:
        print('Carga completada')
        elems = driver.find_elements(By.CLASS_NAME, 'quote_link.js-card')
        print(str((len(elems) - 2) / 2) + ' bulos cargados')

# %%
elems = driver.find_elements(By.CLASS_NAME, 'quote_link.js-card')
(len(elems) - 2) / 2
# Out:
# 1639.0

# %%
bulos = {}

# %%
import urllib
from bs4 import BeautifulSoup
import requests
import numpy
import os
import re
from lxml.html.clean import clean_html
import datetime

# %%
def replace_characters(text):
    text_aux = ''.join(c for c in unicodedata.normalize('NFD', text.strip())
                  if unicodedata.category(c) != 'Mn')
    return re.sub(r'[^\w\s]', '', text_aux.lower().replace(u'\xa0', u' ').replace(u'\n', u' ')).split(" ")

# %%
# HAY QUE REVISAR EL EXCEPT

cont = 0
# elems = driver.find_elements(By.CLASS_NAME, 'quote_link.js-card')
for i in range(2, len(elems), 2):
    
    try:
        title = elems[i].text
        link = elems[i].get_attribute('href')
        
        html = requests.get(link, allow_redirects=False).text
        soup = BeautifulSoup(html, 'html.parser')
        
         # Obtener la fecha de la noticia
        inicio = len(link) - 9
        fin = len(link) -1
        date = link[inicio: fin]
        formated_date =  datetime.datetime.strptime(date, '%Y%m%d').strftime('%d/%m/%Y')
        
        words = dict()
        title_list = re.sub(r'[^\w\s]', '', title.lower()).split(" ")
        
        for w in title_list:
            if w in words:
                words[w] += 1
            else:
                words[w] = 1
                
        new_text = soup.find('div',attrs={'class' : "o-section__row c-article__content"})    
        for text in new_text('p'):
            
            for w in replace_characters(text.get_text()):
                if w in words:
                    words[w] += 1
                else:
                    words[w] = 1
        bulos[cont] = {"titulo" : title, "link" : link, "date" : formated_date, "words_count" : words, "date" : formated_date}
        cont += 1
        
    except:
        print("No se ha podido obtener la informacion de la noticia", i)
# Out:
# No se ha podido obtener la informacion de la noticia 566
# No se ha podido obtener la informacion de la noticia 570
# No se ha podido obtener la informacion de la noticia 586
# No se ha podido obtener la informacion de la noticia 604
# No se ha podido obtener la informacion de la noticia 612
# No se ha podido obtener la informacion de la noticia 748
# No se ha podido obtener la informacion de la noticia 750
# No se ha podido obtener la informacion de la noticia 756
# No se ha podido obtener la informacion de la noticia 1106
# No se ha podido obtener la informacion de la noticia 1182
# No se ha podido obtener la informacion de la noticia 1192
# No se ha podido obtener la informacion de la noticia 1200
# No se ha podido obtener la informacion de la noticia 1206
# No se ha podido obtener la informacion de la noticia 1208
# No se ha podido obtener la informacion de la noticia 1210
# No se ha podido obtener la informacion de la noticia 1212
# No se ha podido obtener la informacion de la noticia 1214
# No se ha podido obtener la informacion de la noticia 1216
# No se ha podido obtener la informacion de la noticia 1220
# No se ha podido obtener la informacion de la noticia 1222
# No se ha podido obtener la informacion de la noticia 1226
# No se ha podido obtener la informacion de la noticia 1228
# No se ha podido obtener la informacion de la noticia 1232
# No se ha podido obtener la informacion de la noticia 1236
# No se ha podido obtener la informacion de la noticia 1238
# No se ha podido obtener la informacion de la noticia 1240
# No se ha podido obtener la informacion de la noticia 1242
# No se ha podido obtener la informacion de la noticia 1244
# No se ha podido obtener la informacion de la noticia 1256
# No se ha podido obtener la informacion de la noticia 1258
# No se ha podido obtener la informacion de la noticia 1260
# No se ha podido obtener la informacion de la noticia 1264
# No se ha podido obtener la informacion de la noticia 1266
# No se ha podido obtener la informacion de la noticia 1268
# No se ha podido obtener la informacion de la noticia 1270
# No se ha podido obtener la informacion de la noticia 1272
# No se ha podido obtener la informacion de la noticia 1276
# No se ha podido obtener la informacion de la noticia 1308
# No se ha podido obtener la informacion de la noticia 1314
# No se ha podido obtener la informacion de la noticia 1316
# No se ha podido obtener la informacion de la noticia 1318
# No se ha podido obtener la informacion de la noticia 1320
# No se ha podido obtener la informacion de la noticia 1322
# No se ha podido obtener la informacion de la noticia 1326
# No se ha podido obtener la informacion de la noticia 1328
# No se ha podido obtener la informacion de la noticia 1336
# No se ha podido obtener la informacion de la noticia 1418
# No se ha podido obtener la informacion de la noticia 1422
# No se ha podido obtener la informacion de la noticia 1424
# No se ha podido obtener la informacion de la noticia 1426
# No se ha podido obtener la informacion de la noticia 1430
# No se ha podido obtener la informacion de la noticia 1432
# No se ha podido obtener la informacion de la noticia 1436
# No se ha podido obtener la informacion de la noticia 1438
# No se ha podido obtener la informacion de la noticia 1440
# No se ha podido obtener la informacion de la noticia 1462
# No se ha podido obtener la informacion de la noticia 1466
# No se ha podido obtener la informacion de la noticia 1470
# No se ha podido obtener la informacion de la noticia 1476
# No se ha podido obtener la informacion de la noticia 1478
# No se ha podido obtener la informacion de la noticia 1482
# No se ha podido obtener la informacion de la noticia 1486
# No se ha podido obtener la informacion de la noticia 1488
# No se ha podido obtener la informacion de la noticia 1492
# No se ha podido obtener la informacion de la noticia 1496
# No se ha podido obtener la informacion de la noticia 1500
# No se ha podido obtener la informacion de la noticia 1502
# No se ha podido obtener la informacion de la noticia 1504
# No se ha podido obtener la informacion de la noticia 1562
# No se ha podido obtener la informacion de la noticia 1578
# No se ha podido obtener la informacion de la noticia 1580
# No se ha podido obtener la informacion de la noticia 1588
# No se ha podido obtener la informacion de la noticia 1594
# No se ha podido obtener la informacion de la noticia 1598
# No se ha podido obtener la informacion de la noticia 1600
# No se ha podido obtener la informacion de la noticia 1602
# No se ha podido obtener la informacion de la noticia 1606
# No se ha podido obtener la informacion de la noticia 1608
# No se ha podido obtener la informacion de la noticia 1610
# No se ha podido obtener la informacion de la noticia 1612
# No se ha podido obtener la informacion de la noticia 1614
# No se ha podido obtener la informacion de la noticia 1620
# No se ha podido obtener la informacion de la noticia 1622
# No se ha podido obtener la informacion de la noticia 1626
# No se ha podido obtener la informacion de la noticia 1636
# No se ha podido obtener la informacion de la noticia 1638
# No se ha podido obtener la informacion de la noticia 1642
# No se ha podido obtener la informacion de la noticia 1646
# No se ha podido obtener la informacion de la noticia 1648
# No se ha podido obtener la informacion de la noticia 1652
# No se ha podido obtener la informacion de la noticia 1744
# No se ha podido obtener la informacion de la noticia 1756
# No se ha podido obtener la informacion de la noticia 1762
# No se ha podido obtener la informacion de la noticia 1764
# No se ha podido obtener la informacion de la noticia 1788
# No se ha podido obtener la informacion de la noticia 1792
# No se ha podido obtener la informacion de la noticia 1794
# No se ha podido obtener la informacion de la noticia 1800
# No se ha podido obtener la informacion de la noticia 1802
# No se ha podido obtener la informacion de la noticia 1804
# No se ha podido obtener la informacion de la noticia 1808
# No se ha podido obtener la informacion de la noticia 1810
# No se ha podido obtener la informacion de la noticia 1814
# No se ha podido obtener la informacion de la noticia 1818
# No se ha podido obtener la informacion de la noticia 1820
# No se ha podido obtener la informacion de la noticia 1822
# No se ha podido obtener la informacion de la noticia 1826
# No se ha podido obtener la informacion de la noticia 1830
# No se ha podido obtener la informacion de la noticia 1836
# No se ha podido obtener la informacion de la noticia 1838
# No se ha podido obtener la informacion de la noticia 1840
# No se ha podido obtener la informacion de la noticia 1842
# No se ha podido obtener la informacion de la noticia 1846
# No se ha podido obtener la informacion de la noticia 1848
# No se ha podido obtener la informacion de la noticia 1850
# No se ha podido obtener la informacion de la noticia 1854
# No se ha podido obtener la informacion de la noticia 1858
# No se ha podido obtener la informacion de la noticia 1860
# No se ha podido obtener la informacion de la noticia 1864
# No se ha podido obtener la informacion de la noticia 1866
# No se ha podido obtener la informacion de la noticia 1872
# No se ha podido obtener la informacion de la noticia 1874
# No se ha podido obtener la informacion de la noticia 1876
# No se ha podido obtener la informacion de la noticia 1880
# No se ha podido obtener la informacion de la noticia 1882
# No se ha podido obtener la informacion de la noticia 1884
# No se ha podido obtener la informacion de la noticia 1886
# No se ha podido obtener la informacion de la noticia 1890
# No se ha podido obtener la informacion de la noticia 1892
# No se ha podido obtener la informacion de la noticia 1896
# No se ha podido obtener la informacion de la noticia 1898
# No se ha podido obtener la informacion de la noticia 1900
# No se ha podido obtener la informacion de la noticia 1914
# No se ha podido obtener la informacion de la noticia 1916
# No se ha podido obtener la informacion de la noticia 1920
# No se ha podido obtener la informacion de la noticia 1922
# No se ha podido obtener la informacion de la noticia 1930
# No se ha podido obtener la informacion de la noticia 1932
# No se ha podido obtener la informacion de la noticia 1934
# No se ha podido obtener la informacion de la noticia 1936
# No se ha podido obtener la informacion de la noticia 1942
# No se ha podido obtener la informacion de la noticia 1946
# No se ha podido obtener la informacion de la noticia 1948
# No se ha podido obtener la informacion de la noticia 1954
# No se ha podido obtener la informacion de la noticia 1956
# No se ha podido obtener la informacion de la noticia 1958
# No se ha podido obtener la informacion de la noticia 1960
# No se ha podido obtener la informacion de la noticia 1962
# No se ha podido obtener la informacion de la noticia 1966
# No se ha podido obtener la informacion de la noticia 1968
# No se ha podido obtener la informacion de la noticia 1970
# No se ha podido obtener la informacion de la noticia 1980
# No se ha podido obtener la informacion de la noticia 1984
# No se ha podido obtener la informacion de la noticia 1986
# No se ha podido obtener la informacion de la noticia 1988
# No se ha podido obtener la informacion de la noticia 1994
# No se ha podido obtener la informacion de la noticia 1996
# No se ha podido obtener la informacion de la noticia 1998
# No se ha podido obtener la informacion de la noticia 2002
# No se ha podido obtener la informacion de la noticia 2004
# No se ha podido obtener la informacion de la noticia 2044
# No se ha podido obtener la informacion de la noticia 2086
# No se ha podido obtener la informacion de la noticia 2092
# No se ha podido obtener la informacion de la noticia 2264
# No se ha podido obtener la informacion de la noticia 2760
# No se ha podido obtener la informacion de la noticia 2762
# No se ha podido obtener la informacion de la noticia 2764
# No se ha podido obtener la informacion de la noticia 2766
# No se ha podido obtener la informacion de la noticia 2768
# No se ha podido obtener la informacion de la noticia 2770
# No se ha podido obtener la informacion de la noticia 2772
# No se ha podido obtener la informacion de la noticia 2774
# No se ha podido obtener la informacion de la noticia 2776
# No se ha podido obtener la informacion de la noticia 2778
# No se ha podido obtener la informacion de la noticia 2780
# No se ha podido obtener la informacion de la noticia 2782
# No se ha podido obtener la informacion de la noticia 2784
# No se ha podido obtener la informacion de la noticia 2786
# No se ha podido obtener la informacion de la noticia 2788
# No se ha podido obtener la informacion de la noticia 2790
# No se ha podido obtener la informacion de la noticia 2792
# No se ha podido obtener la informacion de la noticia 2794
# No se ha podido obtener la informacion de la noticia 2796
# No se ha podido obtener la informacion de la noticia 2798
# No se ha podido obtener la informacion de la noticia 2800
# No se ha podido obtener la informacion de la noticia 2802
# No se ha podido obtener la informacion de la noticia 2804
# No se ha podido obtener la informacion de la noticia 2806
# No se ha podido obtener la informacion de la noticia 2808
# No se ha podido obtener la informacion de la noticia 2810
# No se ha podido obtener la informacion de la noticia 2812
# No se ha podido obtener la informacion de la noticia 2814
# No se ha podido obtener la informacion de la noticia 2816
# No se ha podido obtener la informacion de la noticia 2818
# No se ha podido obtener la informacion de la noticia 2894
# No se ha podido obtener la informacion de la noticia 2896
# No se ha podido obtener la informacion de la noticia 2898
# No se ha podido obtener la informacion de la noticia 2900
# No se ha podido obtener la informacion de la noticia 2902
# No se ha podido obtener la informacion de la noticia 2904
# No se ha podido obtener la informacion de la noticia 2906
# No se ha podido obtener la informacion de la noticia 2908
# No se ha podido obtener la informacion de la noticia 2910
# No se ha podido obtener la informacion de la noticia 2912
# No se ha podido obtener la informacion de la noticia 2914
# No se ha podido obtener la informacion de la noticia 2916
# No se ha podido obtener la informacion de la noticia 2918
# No se ha podido obtener la informacion de la noticia 2920
# No se ha podido obtener la informacion de la noticia 2922
# No se ha podido obtener la informacion de la noticia 2924
# No se ha podido obtener la informacion de la noticia 2926
# No se ha podido obtener la informacion de la noticia 2928
# No se ha podido obtener la informacion de la noticia 2930
# No se ha podido obtener la informacion de la noticia 2932
# No se ha podido obtener la informacion de la noticia 2934
# No se ha podido obtener la informacion de la noticia 2936
# No se ha podido obtener la informacion de la noticia 2938
# No se ha podido obtener la informacion de la noticia 2940
# No se ha podido obtener la informacion de la noticia 2942
# No se ha podido obtener la informacion de la noticia 2946
# No se ha podido obtener la informacion de la noticia 2948
# No se ha podido obtener la informacion de la noticia 2950
# No se ha podido obtener la informacion de la noticia 2952
# No se ha podido obtener la informacion de la noticia 2954
# No se ha podido obtener la informacion de la noticia 2956
# No se ha podido obtener la informacion de la noticia 2958
# No se ha podido obtener la informacion de la noticia 2960
# No se ha podido obtener la informacion de la noticia 2962
# No se ha podido obtener la informacion de la noticia 2964
# No se ha podido obtener la informacion de la noticia 2966
# No se ha podido obtener la informacion de la noticia 2990
# No se ha podido obtener la informacion de la noticia 2992
# No se ha podido obtener la informacion de la noticia 2994
# No se ha podido obtener la informacion de la noticia 2996
# No se ha podido obtener la informacion de la noticia 2998
# No se ha podido obtener la informacion de la noticia 3000
# No se ha podido obtener la informacion de la noticia 3002
# No se ha podido obtener la informacion de la noticia 3004
# No se ha podido obtener la informacion de la noticia 3006
# No se ha podido obtener la informacion de la noticia 3008
# No se ha podido obtener la informacion de la noticia 3010
# No se ha podido obtener la informacion de la noticia 3012
# No se ha podido obtener la informacion de la noticia 3014
# No se ha podido obtener la informacion de la noticia 3016
# No se ha podido obtener la informacion de la noticia 3018
# No se ha podido obtener la informacion de la noticia 3020
# No se ha podido obtener la informacion de la noticia 3022
# No se ha podido obtener la informacion de la noticia 3024
# No se ha podido obtener la informacion de la noticia 3026
# No se ha podido obtener la informacion de la noticia 3030
# No se ha podido obtener la informacion de la noticia 3032
# No se ha podido obtener la informacion de la noticia 3034
# No se ha podido obtener la informacion de la noticia 3036
# No se ha podido obtener la informacion de la noticia 3038
# No se ha podido obtener la informacion de la noticia 3040
# No se ha podido obtener la informacion de la noticia 3042
# No se ha podido obtener la informacion de la noticia 3044
# No se ha podido obtener la informacion de la noticia 3046
# No se ha podido obtener la informacion de la noticia 3048
# No se ha podido obtener la informacion de la noticia 3050
# No se ha podido obtener la informacion de la noticia 3052
# No se ha podido obtener la informacion de la noticia 3054
# No se ha podido obtener la informacion de la noticia 3056
# No se ha podido obtener la informacion de la noticia 3058
# No se ha podido obtener la informacion de la noticia 3060
# No se ha podido obtener la informacion de la noticia 3072
# No se ha podido obtener la informacion de la noticia 3074
# No se ha podido obtener la informacion de la noticia 3076
# No se ha podido obtener la informacion de la noticia 3078
# No se ha podido obtener la informacion de la noticia 3080
# No se ha podido obtener la informacion de la noticia 3082
# No se ha podido obtener la informacion de la noticia 3084
# No se ha podido obtener la informacion de la noticia 3086
# No se ha podido obtener la informacion de la noticia 3088
# No se ha podido obtener la informacion de la noticia 3090
# No se ha podido obtener la informacion de la noticia 3092
# No se ha podido obtener la informacion de la noticia 3094
# No se ha podido obtener la informacion de la noticia 3096
# No se ha podido obtener la informacion de la noticia 3098
# No se ha podido obtener la informacion de la noticia 3100
# No se ha podido obtener la informacion de la noticia 3102
# No se ha podido obtener la informacion de la noticia 3104
# No se ha podido obtener la informacion de la noticia 3106
# No se ha podido obtener la informacion de la noticia 3108
# No se ha podido obtener la informacion de la noticia 3110
# No se ha podido obtener la informacion de la noticia 3122

# %%
# bulos

# %%
len(bulos)
# Out:
# 1353

# %%
with open('fakenewsNewtral.json', 'w') as fp:
    json.dump(bulos, fp)
